# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
src_folder = '/content/drive/MyDrive/project sample/Train'
dest_folder = '/content/drive/MyDrive/project sample/Test'

# %%
# Find all subfolders in the source folder src_folder
directory_contents = os.listdir(src_folder)
print('directory_contents: ', directory_contents)
# Append the path of the src_folder with the sub-folders
sub_folders = []
for item in directory_contents:
  if os.path.isdir(os.path.join(src_folder,item)):
    sub_folders.append(item)
print('sub_folders: ', sub_folders)
# Out:
# directory_contents:  ['Dogs', 'Cats']
# sub_folders:  ['Dogs', 'Cats']

# %%
# Create the same folder structure in destination
for folder_name in sub_folders:
  os.mkdir(os.path.join(dest_folder,folder_name))

# %%
# List full paths of all images in each category/sub-folder
list_files = []
# Find all the files, note that you have to change it to tif if that is the extension
for folder_name in directory_contents:
  files_list = [_ for _ in os.listdir(os.path.join(src_folder, folder_name))]
  # Create the list with full path
  full_path_files_list = []
  for file_name in files_list:
    full_path_files_list.append(os.path.join(src_folder, folder_name, file_name))
  list_files.append(full_path_files_list)
print(list_files[1])
# Out:
# ['/content/drive/MyDrive/project sample/Train/Cats/cat_57.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_18.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_52.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_24.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_33.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_97.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_88.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_85.jpg', '/content/drive/MyDrive/project sample/Train/Cats/cat_42.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_64.jpg', '/content/drive/MyDrive/project sample/Train/Cats/cat_8.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_58.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_1.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_55.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_72.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_41.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_16.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_13.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_95.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_11.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_32.jpg', '/content/drive/MyDrive/project sample/Train/Cats/cat_3.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_92.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_82.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_44.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_15.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_62.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_71.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_28.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_36.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_45.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_78.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_48.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_59.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_84.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_74.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_31.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_37.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_25.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_27.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_80.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_56.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_73.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_89.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_39.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_98.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_66.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_14.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_93.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_46.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_22.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_2.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_75.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_50.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_12.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_30.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_81.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_34.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_70.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_54.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_6.jpeg', '/content/drive/MyDrive/project sample/Train/Cats/cat_4.jpeg', '/content/drive/MyDrive/project sample/T ...

# %%
import random

# Specify the fraction
#this is the splitting percentage. 10% will be sent to test
x = 10

for files_list in list_files:
  # length of the list
  list_len = len(files_list)
  # length of x%
  frac_len = int(list_len * (x/100))
  # select x% of files
  files_to_move = random.sample(files_list, frac_len)
  for single_file in files_to_move:
    # extract the sub-string with subfolder/category and file name
    subfolder_file = '/'.join(single_file.split('/')[-2:])
    # destination path
    dst_folder = os.path.join(dest_folder, subfolder_file)
    # Move the file
    os.replace(single_file, dst_folder)

# %%
for folder_name in sub_folders:
  print(folder_name, len(os.listdir(os.path.join(dest_folder,folder_name))))
# Out:
# Dogs 9
# Cats 9
